# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigyan12345/image/blob/main/image_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
a = 5
# Out:
# Hello World

# %% [markdown]
# # Image Reading
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2082/08/24 08:33 PM

# %%
a=6

# %%
a
# Out:
# 6

# %%
a
# Out:
# 6
